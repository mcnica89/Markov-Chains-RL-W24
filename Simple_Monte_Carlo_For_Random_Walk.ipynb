# %% [markdown]
# <a href="https://colab.research.google.com/github/mcnica89/Markov-Chains-RL-W24/blob/main/Simple_Monte_Carlo_For_Random_Walk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Setup the number of iterations and alpha value
num_iters = 100
alpha = 0.05

initial_guess = 0
value = initial_guess

value_history = np.zeros(num_iters)

# %%
#### SETUP #####
#Setup the initial state
init_s = 0
s = init_s

#Setup  terminal states
min_s = -3
reward_at_min_s = 0.0

max_s = +3
reward_at_max_s = 1.0

#### NUMBER OF LOOPS TO RUN #####
for iter in range(num_iters):

  #Initialize the episode
  episode_is_over = False
  s = init_s

  #### SIMULATE EACH EPISODE #####
  while not episode_is_over:
     #Coinflip: -1 or +1 equal probs
    coinflip = np.random.choice([-1,+1])

    #Update the state
    s += coinflip

    total_return += reward_we_got_now

    #Check if we are at a terminal state?
    #   If so: set return and finish episode
    if s == min_s:
      episode_return = reward_at_min_s
      episode_is_over = True

    if s == max_s:
      episode_return = reward_at_max_s
      episode_is_over = True

  #After the episode: update value function estimate
  value += alpha*(episode_return - value)
  value_history[iter] = value

# %%
print(value)
plt.plot(value_history)
# Out:
# 0.3436048558875441
